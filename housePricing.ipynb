# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import pandas as pd
df = pd.read_csv(r"C:\Users\riapi\OneDrive\Documents\housing_prices_SLR.csv")
df
# Out:
#     AREA  PRICE
# 0   1000   5618
# 1   1030   5201
# 2   1060   4779
# 3   1090   5425
# 4   1120   5657
# 5   1150   4945
# 6   1180   6475
# 7   1210   5352
# 8   1240   6290
# 9   1270   6147
# 10  1300   7718
# 11  1330   7035
# 12  1360   8712
# 13  1390   9457
# 14  1420   7304
# 15  1450   7535
# 16  1480   9968
# 17  1510   7614
# 18  1540   9762
# 19  1570  10067
# 20  1600   8074
# 21  1630  10201
# 22  1660  10051
# 23  1690   9775
# 24  1720  10229
# 25  1750   8314
# 26  1780   9288
# 27  1810  10503
# 28  1840   9763
# 29  1870  11527
# 30  1900   9912
# 31  1930  10204
# 32  1960   9085
# 33  1990  10240
# 34  2020  15220
# 35  2050  12278
# 36  2080  22270
# 37  2110  12574
# 38  2140  12618
# 39  2170  15457
# 40  2200  12793
# 41  2230  12641
# 42  2260  17207
# 43  2290  16969
# 44  2320  16293
# 45  2350  16845
# 46  2380  17604
# 47  2410  17310
# 48  2440  14036
# 49  2470  13699

# %%
df.columns
# Out:
# Index(['AREA', 'PRICE'], dtype='object')

# %%
df.dtypes
# Out:
# AREA     int64
# PRICE    int64
# dtype: object

# %%
df.shape
# Out:
# (50, 2)

# %%
df.head(10)
# Out:
#    AREA  PRICE
# 0  1000   5618
# 1  1030   5201
# 2  1060   4779
# 3  1090   5425
# 4  1120   5657
# 5  1150   4945
# 6  1180   6475
# 7  1210   5352
# 8  1240   6290
# 9  1270   6147

# %%
df.describe()
# Out:
#               AREA       PRICE
# count    50.000000     50.0000
# mean   1735.000000  10480.8200
# std     437.321392   4043.0739
# min    1000.000000   4779.0000
# 25%    1367.500000   7554.7500
# 50%    1735.000000   9940.0000
# 75%    2102.500000  12635.2500
# max    2470.000000  22270.0000

# %%
df.shape[0] #gives rows
# Out:
# 50

# %%
df.shape[1] #gives columns
# Out:
# 2

# %%
list(df.columns)
# Out:
# ['AREA', 'PRICE']

# %%
df.isnull().sum()
# Out:
# AREA     0
# PRICE    0
# dtype: int64

# %%
df.isnull().head()
# Out:
#     AREA  PRICE
# 0  False  False
# 1  False  False
# 2  False  False
# 3  False  False
# 4  False  False

# %%
df['AREA']
# Out:
# 0     1000
# 1     1030
# 2     1060
# 3     1090
# 4     1120
# 5     1150
# 6     1180
# 7     1210
# 8     1240
# 9     1270
# 10    1300
# 11    1330
# 12    1360
# 13    1390
# 14    1420
# 15    1450
# 16    1480
# 17    1510
# 18    1540
# 19    1570
# 20    1600
# 21    1630
# 22    1660
# 23    1690
# 24    1720
# 25    1750
# 26    1780
# 27    1810
# 28    1840
# 29    1870
# 30    1900
# 31    1930
# 32    1960
# 33    1990
# 34    2020
# 35    2050
# 36    2080
# 37    2110
# 38    2140
# 39    2170
# 40    2200
# 41    2230
# 42    2260
# 43    2290
# 44    2320
# 45    2350
# 46    2380
# 47    2410
# 48    2440
# 49    2470
# Name: AREA, dtype: int64

# %%
df['PRICE']
# Out:
# 0      5618
# 1      5201
# 2      4779
# 3      5425
# 4      5657
# 5      4945
# 6      6475
# 7      5352
# 8      6290
# 9      6147
# 10     7718
# 11     7035
# 12     8712
# 13     9457
# 14     7304
# 15     7535
# 16     9968
# 17     7614
# 18     9762
# 19    10067
# 20     8074
# 21    10201
# 22    10051
# 23     9775
# 24    10229
# 25     8314
# 26     9288
# 27    10503
# 28     9763
# 29    11527
# 30     9912
# 31    10204
# 32     9085
# 33    10240
# 34    15220
# 35    12278
# 36    22270
# 37    12574
# 38    12618
# 39    15457
# 40    12793
# 41    12641
# 42    17207
# 43    16969
# 44    16293
# 45    16845
# 46    17604
# 47    17310
# 48    14036
# 49    13699
# Name: PRICE, dtype: int64

# %%
df[['AREA','PRICE']]
# Out:
#     AREA  PRICE
# 0   1000   5618
# 1   1030   5201
# 2   1060   4779
# 3   1090   5425
# 4   1120   5657
# 5   1150   4945
# 6   1180   6475
# 7   1210   5352
# 8   1240   6290
# 9   1270   6147
# 10  1300   7718
# 11  1330   7035
# 12  1360   8712
# 13  1390   9457
# 14  1420   7304
# 15  1450   7535
# 16  1480   9968
# 17  1510   7614
# 18  1540   9762
# 19  1570  10067
# 20  1600   8074
# 21  1630  10201
# 22  1660  10051
# 23  1690   9775
# 24  1720  10229
# 25  1750   8314
# 26  1780   9288
# 27  1810  10503
# 28  1840   9763
# 29  1870  11527
# 30  1900   9912
# 31  1930  10204
# 32  1960   9085
# 33  1990  10240
# 34  2020  15220
# 35  2050  12278
# 36  2080  22270
# 37  2110  12574
# 38  2140  12618
# 39  2170  15457
# 40  2200  12793
# 41  2230  12641
# 42  2260  17207
# 43  2290  16969
# 44  2320  16293
# 45  2350  16845
# 46  2380  17604
# 47  2410  17310
# 48  2440  14036
# 49  2470  13699

# %%
df[df.index==2]
# Out:
#    AREA  PRICE
# 2  1060   4779

# %%
df[df.index.isin(range(0,20))]
# Out:
#     AREA  PRICE
# 0   1000   5618
# 1   1030   5201
# 2   1060   4779
# 3   1090   5425
# 4   1120   5657
# 5   1150   4945
# 6   1180   6475
# 7   1210   5352
# 8   1240   6290
# 9   1270   6147
# 10  1300   7718
# 11  1330   7035
# 12  1360   8712
# 13  1390   9457
# 14  1420   7304
# 15  1450   7535
# 16  1480   9968
# 17  1510   7614
# 18  1540   9762
# 19  1570  10067

# %%
df.loc[7]
# Out:
# AREA     1210
# PRICE    5352
# Name: 7, dtype: int64

# %%
df.loc[2:7]
# Out:
#    AREA  PRICE
# 2  1060   4779
# 3  1090   5425
# 4  1120   5657
# 5  1150   4945
# 6  1180   6475
# 7  1210   5352

# %%
df.iloc[2]
# Out:
# AREA     1060
# PRICE    4779
# Name: 2, dtype: int64

# %%
df.iloc[7:17, :2]
# Out:
#     AREA  PRICE
# 7   1210   5352
# 8   1240   6290
# 9   1270   6147
# 10  1300   7718
# 11  1330   7035
# 12  1360   8712
# 13  1390   9457
# 14  1420   7304
# 15  1450   7535
# 16  1480   9968

# %%
df.loc[[7,12,13,17,22,27]]
# Out:
#     AREA  PRICE
# 7   1210   5352
# 12  1360   8712
# 13  1390   9457
# 17  1510   7614
# 22  1660  10051
# 27  1810  10503

# %%
df.loc[:7,['AREA','PRICE']]
# Out:
#    AREA  PRICE
# 0  1000   5618
# 1  1030   5201
# 2  1060   4779
# 3  1090   5425
# 4  1120   5657
# 5  1150   4945
# 6  1180   6475
# 7  1210   5352

# %%
df.iloc[0:2,:]
# Out:
#    AREA  PRICE
# 0  1000   5618
# 1  1030   5201

# %%
df.loc[df['AREA']==1030,['AREA']]=1777

# %%
df.head()
# Out:
#    AREA  PRICE
# 0  1000   5618
# 1  1777   5201
# 2  1060   4779
# 3  1090   5425
# 4  1120   5657

# %%
df[df.AREA==1777]
# Out:
#    AREA  PRICE
# 1  1777   5201

# %%
df[df.PRICE==4779]
# Out:
#    AREA  PRICE
# 2  1060   4779

# %%
df.loc[df['AREA']>2020,['PRICE']]
# Out:
#     PRICE
# 35  12278
# 36  22270
# 37  12574
# 38  12618
# 39  15457
# 40  12793
# 41  12641
# 42  17207
# 43  16969
# 44  16293
# 45  16845
# 46  17604
# 47  17310
# 48  14036
# 49  13699

# %%
df.rename(columns={'AREA':'OURAREA'})
# Out:
#     OURAREA  PRICE
# 0      1000   5618
# 1      1777   5201
# 2      1060   4779
# 3      1090   5425
# 4      1120   5657
# 5      1150   4945
# 6      1180   6475
# 7      1210   5352
# 8      1240   6290
# 9      1270   6147
# 10     1300   7718
# 11     1330   7035
# 12     1360   8712
# 13     1390   9457
# 14     1420   7304
# 15     1450   7535
# 16     1480   9968
# 17     1510   7614
# 18     1540   9762
# 19     1570  10067
# 20     1600   8074
# 21     1630  10201
# 22     1660  10051
# 23     1690   9775
# 24     1720  10229
# 25     1750   8314
# 26     1780   9288
# 27     1810  10503
# 28     1840   9763
# 29     1870  11527
# 30     1900   9912
# 31     1930  10204
# 32     1960   9085
# 33     1990  10240
# 34     2020  15220
# 35     2050  12278
# 36     2080  22270
# 37     2110  12574
# 38     2140  12618
# 39     2170  15457
# 40     2200  12793
# 41     2230  12641
# 42     2260  17207
# 43     2290  16969
# 44     2320  16293
# 45     2350  16845
# ...

# %%
df.columns=['OURAREA','OURPRICE']

# %%
df.head()
# Out:
#    OURAREA  OURPRICE
# 0     1000      5618
# 1     1777      5201
# 2     1060      4779
# 3     1090      5425
# 4     1120      5657

# %%
df.mean()
# Out:
# OURAREA      1749.94
# OURPRICE    10480.82
# dtype: float64

# %%
df.mode()
# Out:
#     OURAREA  OURPRICE
# 0      1000      4779
# 1      1060      4945
# 2      1090      5201
# 3      1120      5352
# 4      1150      5425
# 5      1180      5618
# 6      1210      5657
# 7      1240      6147
# 8      1270      6290
# 9      1300      6475
# 10     1330      7035
# 11     1360      7304
# 12     1390      7535
# 13     1420      7614
# 14     1450      7718
# 15     1480      8074
# 16     1510      8314
# 17     1540      8712
# 18     1570      9085
# 19     1600      9288
# 20     1630      9457
# 21     1660      9762
# 22     1690      9763
# 23     1720      9775
# 24     1750      9912
# 25     1777      9968
# 26     1780     10051
# 27     1810     10067
# 28     1840     10201
# 29     1870     10204
# 30     1900     10229
# 31     1930     10240
# 32     1960     10503
# 33     1990     11527
# 34     2020     12278
# 35     2050     12574
# 36     2080     12618
# 37     2110     12641
# 38     2140     12793
# 39     2170     13699
# ...

# %%
df['updated_data'] = df['OURAREA']/df['OURPRICE']
df
# Out:
#     OURAREA  OURPRICE  updated_data
# 0      1000      5618      0.177999
# 1      1777      5201      0.341665
# 2      1060      4779      0.221804
# 3      1090      5425      0.200922
# 4      1120      5657      0.197985
# 5      1150      4945      0.232558
# 6      1180      6475      0.182239
# 7      1210      5352      0.226084
# 8      1240      6290      0.197138
# 9      1270      6147      0.206605
# 10     1300      7718      0.168437
# 11     1330      7035      0.189055
# 12     1360      8712      0.156107
# 13     1390      9457      0.146981
# 14     1420      7304      0.194414
# 15     1450      7535      0.192435
# 16     1480      9968      0.148475
# 17     1510      7614      0.198319
# 18     1540      9762      0.157755
# 19     1570     10067      0.155955
# 20     1600      8074      0.198167
# 21     1630     10201      0.159788
# 22     1660     10051      0.165158
# 23     1690      9775      0.172890
# 24     1720     10229      0.168149
# ...

# %%
df['updated_data'].value_counts()
# Out:
# 0.177999    1
# 0.167807    1
# 0.172332    1
# 0.188467    1
# 0.162228    1
# 0.191687    1
# 0.189142    1
# 0.215740    1
# 0.194336    1
# 0.132720    1
# 0.166965    1
# 0.093399    1
# 0.169599    1
# 0.341665    1
# 0.140389    1
# 0.171969    1
# 0.176410    1
# 0.131342    1
# 0.134952    1
# 0.142392    1
# 0.139507    1
# 0.135197    1
# 0.139226    1
# 0.173839    1
# 0.191645    1
# 0.210488    1
# 0.168149    1
# 0.172890    1
# 0.221804    1
# 0.200922    1
# 0.197985    1
# 0.232558    1
# 0.182239    1
# 0.226084    1
# 0.197138    1
# 0.206605    1
# 0.168437    1
# 0.189055    1
# 0.156107    1
# 0.146981    1
# 0.194414    1
# 0.192435    1
# 0.148475    1
# 0.198319    1
# 0.157755    1
# 0.155955    1
# 0.198167    1
# 0.159788    1
# 0.165158    1
# 0.180305    1
# Name: updated_data, dtype: int64

# %%
df['OURPRICE'].value_counts()
# Out:
# 5618     1
# 12574    1
# 10503    1
# 9763     1
# 11527    1
# 9912     1
# 10204    1
# 9085     1
# 10240    1
# 15220    1
# 12278    1
# 22270    1
# 12618    1
# 5201     1
# 15457    1
# 12793    1
# 12641    1
# 17207    1
# 16969    1
# 16293    1
# 16845    1
# 17604    1
# 17310    1
# 14036    1
# 9288     1
# 8314     1
# 10229    1
# 9775     1
# 4779     1
# 5425     1
# 5657     1
# 4945     1
# 6475     1
# 5352     1
# 6290     1
# 6147     1
# 7718     1
# 7035     1
# 8712     1
# 9457     1
# 7304     1
# 7535     1
# 9968     1
# 7614     1
# 9762     1
# 10067    1
# 8074     1
# 10201    1
# 10051    1
# 13699    1
# Name: OURPRICE, dtype: int64

# %%
df.groupby(['OURAREA','OURPRICE','updated_data']).mean()
# Out:
# Empty DataFrame
# Columns: []
# ...

# %%
df[['OURAREA','OURPRICE']].plot.line()
# Out:
# <Axes: >

# %%
df[['OURAREA','OURPRICE']].plot.line(figsize=(10,10),color={'OURAREA':"pink","OURPRICE":"black"})
# Out:
# <Axes: >

# %%
df.plot.line(subplots=True)
# Out:
# array([<Axes: >, <Axes: >, <Axes: >], dtype=object)

# %%
df['OURPRICE'].value_counts().plot.bar(figsize=(30,10))
# Out:
# <Axes: >

# %%
df.boxplot(figsize=(30,10),column=['OURPRICE'], by='OURPRICE')
# Out:
# <Axes: title={'center': 'OURPRICE'}, xlabel='OURPRICE'>

# %%
plt.scatter(df['OURAREA'], df['OURPRICE'])
plt.show()

# %%
z=np.polyfit(df['OURAREA'],df["OURPRICE"],1)
p=np.poly1d(z)
plt.scatter(df['OURAREA'], df['OURPRICE'])
plt.show()

# %%
plt.plot(df['OURAREA'],df['OURAREA'], color="blue")
plt.plot(df['OURPRICE'],df['OURPRICE'], color="pink")
plt.legend(['OURAREA','OURPRICE'])
plt.show()

# %%
plt.bar(df['OURAREA'], height=df['OURPRICE'], color=['pink','gray'])
plt.show()

# %%
plt.scatter(df['OURAREA'], df['OURPRICE'], c=df['OURAREA'], cmap='viridis')
plt.show()
